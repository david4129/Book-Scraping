# %% [markdown]
# <a href="https://colab.research.google.com/github/david4129/Book-Scraping/blob/main/Untitled49.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scraping Site with BeautifulSoup Library
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#Libraries">Libraries</a></li>
# <li><a href="#Scraping">Web Scraping</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#model">Modelling</a></li>
#
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## INTRODUCTION
#
# In this Project, we are going to be scraping data from bookstoscrape.com, a demo site for webscraping purposes. Our goal is to obtain data from this site, store the data in a dataframe and then perform data analysis on the dataset obtained. We are going to make use of the BeautifulSoup and requests library for the scraping. To complete this project, we are going to build a linear regression model to predict the prices of books.

# %% [markdown]
# <a id = 'Libraries'></a>
# ## Libraries

# %%
#import libraries
import os
import re
import sys
from google.colab import drive
sys.path.append('/content/drive/My Drive/Colab Notebooks')
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_squared_error

# %% [markdown]
# <a id = "Scraping"></a>
# ## Web Scraping

# %%
#Scrape data on books from the website
#Return a DataFrame containing the information

#Returns a list of internal links of books as well as their categories
def return_urls():
  book_url = requests.get('http://books.toscrape.com/catalogue/category/books_1/index.html').text
  list_book = []
  book_parsed = BeautifulSoup(book_url, 'lxml')
  first_body = book_parsed.find_all('li')
  for i in book_parsed.find_all('a', href = re.compile('\.\./books/[A-Za-z0-9]+')):
    new_url = 'http://books.toscrape.com/catalogue/category' + i['href'][2:]
    category = i.text.strip()
    list_book.append([new_url, category])
  return list_book


#Returns a Dataframe consisting of 
def return_books():
  book_dic = {}
  title_list = []
  price_list = []
  ratings = []
  cat_list = []
  packed_url = return_urls()
  for i in packed_url:
    obt_url = requests.get(i[0]).text
    parsed_url = BeautifulSoup(obt_url, 'lxml')
    books = parsed_url.find_all('li', class_ = 'col-xs-6 col-sm-4 col-md-3 col-lg-3')
    for book in books:
      book_title = book.find('h3').text
      book_price = book.find('p', class_ = 'price_color').text[1:]
      rating = book.article.p['class'][1]
      categories = i[1]

      title_list.append(book_title)
      price_list.append(book_price)
      ratings.append(rating)
      cat_list.append(categories)
  book_dic['Title'] = title_list
  book_dic['Price'] = price_list
  book_dic['ratings'] = ratings
  book_dic['category'] = cat_list
  return pd.DataFrame(book_dic)

df = return_books()
df
# Out:
#                                   Title   Price ratings  category
# 0               It's Only the Himalayas  £45.17     Two    Travel
# 1           Full Moon over Noahâs ...  £49.43    Four    Travel
# 2        See America: A Celebration ...  £48.87   Three    Travel
# 3    Vagabonding: An Uncommon Guide ...  £36.94     Two    Travel
# 4                  Under the Tuscan Sun  £37.33   Three    Travel
# ..                                  ...     ...     ...       ...
# 512              Why the Right Went ...  £52.65    Four  Politics
# 513      Equal Is Unfair: America's ...  £56.86     One  Politics
# 514                      Amid the Chaos  £36.58     One  Cultural
# 515                          Dark Notes  £19.19    Five   Erotica
# 516              The Long Shadow of ...  £10.97     One     Crime
#
# [517 rows x 4 columns]

# %% [markdown]
# <a id = "eda"></a>
# ## Exploratory Data Analysis

# %%
df.head()
# Out:
#                                 Title   Price ratings category
# 0             It's Only the Himalayas  £45.17     Two   Travel
# 1         Full Moon over Noahâs ...  £49.43    Four   Travel
# 2      See America: A Celebration ...  £48.87   Three   Travel
# 3  Vagabonding: An Uncommon Guide ...  £36.94     Two   Travel
# 4                Under the Tuscan Sun  £37.33   Three   Travel

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     517 non-null    object
#  1   Price     517 non-null    object
#  2   ratings   517 non-null    object
#  3   category  517 non-null    object
# dtypes: object(4)
# memory usage: 16.3+ KB

# %%
#Remove the currency symbol from our price feature
df['Price'] = df['Price'].apply(lambda x: x[1:])
df.head()
# Out:
#                                 Title  Price ratings category
# 0             It's Only the Himalayas  45.17     Two   Travel
# 1         Full Moon over Noahâs ...  49.43    Four   Travel
# 2      See America: A Celebration ...  48.87   Three   Travel
# 3  Vagabonding: An Uncommon Guide ...  36.94     Two   Travel
# 4                Under the Tuscan Sun  37.33   Three   Travel

# %%
#Convert the price feature to float
df['Price'] = df['Price'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     517 non-null    object
#  1   Price     517 non-null    float64
#  2   ratings   517 non-null    object
#  3   category  517 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 16.3+ KB

# %%
df.describe()
# Out:
#             Price
# count  517.000000
# mean    35.315068
# std     14.341524
# min     10.010000
# 25%     22.540000
# 50%     36.260000
# 75%     48.190000
# max     59.990000

# %%
#The number of each rating in our dataset
rating_value = df['ratings'].value_counts()
rating_value
# Out:
# One      122
# Two      105
# Five     104
# Three     98
# Four      88
# Name: ratings, dtype: int64

# %%
#Visualisation of the number of each rating in our dataset
sns.countplot(x = 'ratings', data = df, palette = 'Purples')

# %%
#The number of each category in our dataset
no_of_categories  = df['category'].value_counts()
no_of_categories
# Out:
# Childrens             20
# Fiction               20
# Add a comment         20
# Young Adult           20
# Default               20
# Mystery               20
# Nonfiction            20
# Food and Drink        20
# Fantasy               20
# Romance               20
# Sequential Art        20
# Historical Fiction    20
# Poetry                19
# Classics              19
# History               18
# Womens Fiction        17
# Horror                17
# Science Fiction       16
# Science               14
# Music                 13
# Business              12
# Travel                11
# Thriller              11
# Philosophy            11
# Humor                 10
# Autobiography          9
# Art                    8
# Religion               7
# Psychology             7
# Spirituality           6
# New Adult              6
# Christian Fiction      6
# Self Help              5
# Sports and Games       5
# Biography              5
# Health                 4
# Contemporary           3
# ...

# %%
#Average price per category
avg_price_cat = df.groupby(by = 'category').mean()
avg_price_cat
# Out:
#                         Price
# category
# Academic            13.120000
# Add a comment       34.643000
# Adult Fiction       15.360000
# Art                 38.520000
# Autobiography       37.053333
# Biography           33.662000
# Business            32.460000
# Childrens           36.402500
# Christian           42.496667
# Christian Fiction   34.385000
# Classics            36.545263
# Contemporary        36.200000
# Crime               10.970000
# Cultural            36.580000
# Default             35.024000
# Erotica             19.190000
# Fantasy             39.654000
# Fiction             37.696500
# Food and Drink      31.399000
# Health              51.452500
# Historical          22.830000
# Historical Fiction  35.379000
# History             37.295000
# Horror              35.949412
# Humor               33.501000
# Music               35.636923
# Mystery             32.794000
# New Adult           46.383333
# Nonfiction          32.690000
# ...

# %%
#Categories with prices higher than the 75th percentile
upper_price = avg_price_cat['Price'].quantile(0.75)
avg_price_cat[avg_price_cat['Price'] > upper_price]
# Out:
#                       Price
# category
# Art               38.520000
# Christian         42.496667
# Fantasy           39.654000
# Fiction           37.696500
# Health            51.452500
# New Adult         46.383333
# Novels            54.810000
# Parenting         37.350000
# Politics          53.613333
# Self Help         40.620000
# Sports and Games  41.166000
# Suspense          58.330000
# Travel            39.794545

# %% [markdown]
# <a id = "Modelling"></a>
# ## Modelling

# %%
#Obtain the list of categorical features
obj_cat = [x for x in df.columns if df[x].dtype == object]

# %%
#Perform label encoding on data
encoder = OrdinalEncoder()
df[obj_cat] = encoder.fit_transform(df[obj_cat])

# %%
#Split our dataset in training and test data
X, y = df.drop('Price', axis = 1), df['Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#Train our linear regression model
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Make predictions 
prediction = lr.predict(X_test)
error = np.sqrt(mean_squared_error(y_test, prediction))

# %%
error
# Out:
# 13.530153674305028
